# %%
# %run linear_model.py
gdp_per_capita[:30]
# Out:
#                 Country       2015    Value
# 0           Afghanistan    599.994      NaN
# 1               Albania   3995.383      NaN
# 2               Algeria   4318.135      NaN
# 3                Angola   4100.315      NaN
# 4   Antigua and Barbuda  14414.302      NaN
# 5             Argentina  13588.846      NaN
# 6               Armenia   3534.860      NaN
# 7             Australia  50961.865      1.1
# 8             Australia  50961.865      1.1
# 9             Australia  50961.865      1.1
# 10            Australia  50961.865     20.0
# 11            Australia  50961.865     20.0
# 12            Australia  50961.865     20.0
# 13            Australia  50961.865      2.3
# 14            Australia  50961.865      2.3
# 15            Australia  50961.865      2.3
# 16            Australia  50961.865  31588.0
# 17            Australia  50961.865  31588.0
# 18            Australia  50961.865  31588.0
# 19            Australia  50961.865  62627.0
# ...

# %%
oecd_bli[:20]
# Out:
#    LOCATION         Country INDICATOR                           Indicator  \
# 0       AUS       Australia   HO_BASE  Dwellings without basic facilities
# 1       AUT         Austria   HO_BASE  Dwellings without basic facilities
# 2       BEL         Belgium   HO_BASE  Dwellings without basic facilities
# 3       CAN          Canada   HO_BASE  Dwellings without basic facilities
# 4       CZE  Czech Republic   HO_BASE  Dwellings without basic facilities
# 5       DNK         Denmark   HO_BASE  Dwellings without basic facilities
# 6       FIN         Finland   HO_BASE  Dwellings without basic facilities
# 7       FRA          France   HO_BASE  Dwellings without basic facilities
# 8       DEU         Germany   HO_BASE  Dwellings without basic facilities
# 9       GRC          Greece   HO_BASE  Dwellings without basic facilities
# 10      HUN         Hungary   HO_BASE  Dwellings without basic facilities
# 11      ISL         Iceland   HO_BASE  Dwellings without basic facilities
# ...

# %%
# %run linear_model.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# h:\ComputerScience\Hands-On_Machine_Learning\chapter1\linear_model.py in <module>
#       5 from fetch_data import get_oecd
#       6 from fetch_data import get_gdp
# ----> 7 from make_dataframe import prepare_country_stats
#       8
#       9 # Load the data
#
# ModuleNotFoundError: No module named 'make_dataframe'

# %%
# %run linear_model.py
gdata[:30]
# Out:
#                 Country       2015    Value
# 0           Afghanistan    599.994      NaN
# 1               Albania   3995.383      NaN
# 2               Algeria   4318.135      NaN
# 3                Angola   4100.315      NaN
# 4   Antigua and Barbuda  14414.302      NaN
# 5             Argentina  13588.846      NaN
# 6               Armenia   3534.860      NaN
# 7             Australia  50961.865      1.1
# 8             Australia  50961.865      1.1
# 9             Australia  50961.865      1.1
# 10            Australia  50961.865     20.0
# 11            Australia  50961.865     20.0
# 12            Australia  50961.865     20.0
# 13            Australia  50961.865      2.3
# 14            Australia  50961.865      2.3
# 15            Australia  50961.865      2.3
# 16            Australia  50961.865  31588.0
# 17            Australia  50961.865  31588.0
# 18            Australia  50961.865  31588.0
# 19            Australia  50961.865  62627.0
# ...

# %%
odata[:30]
# Out:
#             Country  Value
# 0         Australia    1.1
# 1           Austria    1.0
# 2           Belgium    2.0
# 3            Canada    0.2
# 4    Czech Republic    0.9
# 5           Denmark    0.9
# 6           Finland    0.6
# 7            France    0.5
# 8           Germany    0.1
# 9            Greece    0.7
# 10          Hungary    4.8
# 11          Iceland    0.4
# 12          Ireland    0.2
# 13            Italy    1.1
# 14            Japan    6.4
# 15            Korea    4.2
# 16       Luxembourg    0.1
# 17           Mexico    4.2
# 18      Netherlands    0.0
# 19      New Zealand    0.2
# 20           Norway    0.3
# 21           Poland    3.2
# 22         Portugal    0.9
# 23  Slovak Republic    0.6
# 24            Spain    0.1
# 25           Sweden    0.0
# 26      Switzerland    0.0
# 27           Turkey   12.7
# 28   United Kingdom    0.2
# 29    United States    0.1

# %%
import numpy as np
print(np.c_.__doc__)
# Out:
#     Translates slice objects to concatenation along the second axis.
#
#     This is short-hand for ``np.r_['-1,2,0', index expression]``, which is
#     useful because of its common occurrence. In particular, arrays will be
#     stacked along their last axis after being upgraded to at least 2-D with
#     1's post-pended to the shape (column vectors made out of 1-D arrays).
#
#     See Also
#     --------
#     column_stack : Stack 1-D arrays as columns into a 2-D array.
#     r_ : For more detailed documentation.
#
#     Examples
#     --------
#     >>> np.c_[np.array([1,2,3]), np.array([4,5,6])]
#     array([[1, 4],
#            [2, 5],
#            [3, 6]])
#     >>> np.c_[np.array([[1,2,3]]), 0, 0, np.array([[4,5,6]])]
#     array([[1, 2, 3, ..., 4, 5, 6]])

# %%
# %run linear_model.py
x.reshape(1,-1)
x
# Out:
#             Country  Value        2015
# 0         Australia    1.1   50961.865
# 1           Austria    1.0   43724.031
# 2           Belgium    2.0   40106.632
# 3            Canada    0.2   43331.961
# 4    Czech Republic    0.9   17256.918
# 5           Denmark    0.9   52114.165
# 6           Finland    0.6   41973.988
# 7            France    0.5   37675.006
# 8           Germany    0.1   40996.511
# 9            Greece    0.7   18064.288
# 10          Hungary    4.8   12239.894
# 11          Iceland    0.4   50854.583
# 12          Ireland    0.2   51350.744
# 13            Italy    1.1   29866.581
# 14            Japan    6.4   32485.545
# 15            Korea    4.2   27195.197
# 16       Luxembourg    0.1  101994.093
# 17           Mexico    4.2    9009.280
# 18      Netherlands    0.0   43603.115
# 19      New Zealand    0.2   37044.891
# 20           Norway    0.3   74822.106
# 21           Poland    3.2   12495.334
# 22         Portugal    0.9   19121.592
# ...

# %%
print(x.reshape(-1,1))
# Out:
# [[50961.865]
#  [43724.031]
#  [40106.632]
#  ...
#  [ 9054.914]
#  [20732.482]
#  [    0.   ]]
