# %%
# %matplotlib inline
# %run create_train_test.py
import matplotlib.pyplot as plt
import pandas as np

# %%
ts_copy = test_set.copy()
ts_copy["rooms_per_household"]=ts_copy["total_rooms"]/ts_copy["households"]
ts_copy["bedrooms_per_room"]=ts_copy["total_rooms"]/ts_copy["total_bedrooms"]
ts_copy["population_per_household"]=ts_copy["population"]/ts_copy["households"]

# %%
corr_matrix = ts_copy.corr()
corr_matrix["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value          1.000000
# median_income               0.705917
# bedrooms_per_room           0.415456
# rooms_per_household         0.180118
# total_rooms                 0.122957
# housing_median_age          0.113962
# households                  0.050354
# total_bedrooms              0.027529
# population                 -0.026668
# longitude                  -0.026673
# latitude                   -0.166073
# population_per_household   -0.209991
# Name: median_house_value, dtype: float64

# %%
ts_copy.plot(kind="scatter",x="median_house_value",y="bedrooms_per_room",alpha=0.1)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='bedrooms_per_room'>
